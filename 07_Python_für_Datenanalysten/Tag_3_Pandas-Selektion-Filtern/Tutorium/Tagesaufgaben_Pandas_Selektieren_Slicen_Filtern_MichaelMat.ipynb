# %% [markdown]
# <br><br><center><h1 style="font-size:2em;color:#2467C0">Tagesaufgaben: Pandas DataFrames
# <br>Selektieren, Slicen, Filtern</h1></center>

# %%
# Deine Imports:
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# #### Taxis-Daten analysieren

# %%
# Datensatz taxis laden:
taxis = sns.load_dataset('taxis')

# %% [markdown]
# 1. Verschaffe dir einen Überblick über die ersten fünf Einträge,
# um ein Gefühl für den Datensatz zu bekommen.
# <br>Lasse dir außerdem die Gestalt des DataFrames sowie eine Statistik aller numerischen Spalten.

# %%
taxis.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# 1  Upper West Side South      Manhattan       Manhattan
# 2           West Village      Manhattan       Manhattan
# 3         Yorkville West      Manhattan       Manhattan
# 4         Yorkville West      Manhattan       Manhattan

# %%
taxis.shape
# Out:
# (6433, 14)

# %%
taxis.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6433                           6433
# mean   2019-03-16 08:31:28.514223616  2019-03-16 08:45:49.491217408
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:50:34            2019-03-08 16:12:51
# 50%              2019-03-15 21:46:58            2019-03-15 22:06:44
# 75%              2019-03-23 17:41:38            2019-03-23 17:51:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# 50%       1.000000     1.640000     9.500000     1.70000     0.000000
# 75%       2.000000     3.210000    15.000000     2.80000     0.000000
# max       6.000000    36.700000   150.000000    33.20000    24.020000
# std       1.203768     3.827867    11.551804     2.44856     1.415267
#
#              total
# count  6433.000000
# mean     18.517794
# min       1.300000
# 25%      10.800000
# 50%      14.160000
# 75%      20.300000
# max     174.820000
# std      13.815570

# %% [markdown]
# 2. Lass dir eine Liste aller Spaltennamen ausgeben. <br>
# Selektiere außerdem fare, tip, distance, payment.

# %%
taxis.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
taxis[['fare', 'tip', 'distance', 'payment']]
# Out:
#       fare   tip  distance      payment
# 0      7.0  2.15      1.60  credit card
# 1      5.0  0.00      0.79         cash
# 2      7.5  2.36      1.37  credit card
# 3     27.0  6.15      7.70  credit card
# 4      9.0  1.10      2.16  credit card
# ...    ...   ...       ...          ...
# 6428   4.5  1.06      0.75  credit card
# 6429  58.0  0.00     18.74  credit card
# 6430  16.0  0.00      4.14         cash
# 6431   6.0  0.00      1.12  credit card
# 6432  15.0  3.36      3.85  credit card
#
# [6433 rows x 4 columns]

# %% [markdown]
# 3. Welche Taxifarben und welche Bezahlmethoden gibt es (die Labels)?

# %%
taxis['color'].unique()
# Out:
# array(['yellow', 'green'], dtype=object)

# %%
taxis['payment'].unique()
# Out:
# array(['credit card', 'cash', nan], dtype=object)

# %% [markdown]
# 4. Wie viele Taxis der verschiedenen Farben haben wir (Stückzahlen)?

# %%
taxis.value_counts('color')
# Out:
# color
# yellow    5451
# green      982
# Name: count, dtype: int64

# %% [markdown]
# 5. Welchen Anteil nehmen die verschiedenen Bezahlmethoden an allen Zahlungen ein?

# %%
taxis.value_counts('payment', normalize=True)
# Out:
# payment
# credit card    0.716388
# cash           0.283612
# Name: proportion, dtype: float64

# %% [markdown]
# 6. Entferne für die weitere Arbeit pickup_zone und dropoff_zone aus dem DataFrame.<br>
# Füge außerdem eine Spalte distance_km hinzu, in der die Fahrtstrecke in Kilometern zu finden ist (distance ist in Meilen!).<br>
# Überprüfe, ob das wirklich geklappt hat!

# %%
taxis.drop(['pickup_zone', 'dropoff_zone'], axis=True, inplace=True)

# %%
taxis['distance_km'] = taxis['distance'] * 1.60934

# %%
# Variante um die neue Column neben der alten 'distance' Column zu haben
# taxis.insert(taxis.columns.get_loc('distance') + 1, 'distance_km', taxis['distance'] * 1.60934)

# %%
taxis.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment pickup_borough dropoff_borough  \
# 0    0.0  12.95  yellow  credit card      Manhattan       Manhattan
# 1    0.0   9.30  yellow         cash      Manhattan       Manhattan
# 2    0.0  14.16  yellow  credit card      Manhattan       Manhattan
# 3    0.0  36.95  yellow  credit card      Manhattan       Manhattan
# 4    0.0  13.40  yellow  credit card      Manhattan       Manhattan
#
#    distance_km
# 0     2.574944
# 1     1.271379
# 2     2.204796
# 3    12.391918
# 4     3.476174

# %% [markdown]
# 7. Wie würdest du am effektivsten den Ausschnitt der Daten auswählen,
# der Gleitkommazahlen enthält?

# %%
taxis.select_dtypes('float')
# Out:
#       distance  fare   tip  tolls  total  distance_km
# 0         1.60   7.0  2.15    0.0  12.95     2.574944
# 1         0.79   5.0  0.00    0.0   9.30     1.271379
# 2         1.37   7.5  2.36    0.0  14.16     2.204796
# 3         7.70  27.0  6.15    0.0  36.95    12.391918
# 4         2.16   9.0  1.10    0.0  13.40     3.476174
# ...        ...   ...   ...    ...    ...          ...
# 6428      0.75   4.5  1.06    0.0   6.36     1.207005
# 6429     18.74  58.0  0.00    0.0  58.80    30.159032
# 6430      4.14  16.0  0.00    0.0  17.30     6.662668
# 6431      1.12   6.0  0.00    0.0   6.80     1.802461
# 6432      3.85  15.0  3.36    0.0  20.16     6.195959
#
# [6433 rows x 6 columns]

# %% [markdown]
# 8. Was ist das höchste Trinkgeld, das einer unserer Taxifahrer bekommen hat?

# %%
taxis.tip.max()
# Out:
# np.float64(33.2)

# %% [markdown]
# 9. Lass dir die gesamte Zeile für dieses Trinkgeld anzeigen.

# %%
taxis.loc[taxis['tip'].idxmax()]
# Out:
# pickup             2019-03-12 19:52:36
# dropoff            2019-03-12 19:52:55
# passengers                           3
# distance                           0.0
# fare                             120.0
# tip                               33.2
# tolls                             12.5
# total                            166.0
# color                           yellow
# payment                    credit card
# pickup_borough                     NaN
# dropoff_borough                    NaN
# distance_km                        0.0
# 745   13.26   5.76  66.32  yellow  credit card      Manhattan          Queens
# 1179  14.12   5.76  61.18  yellow  credit card      Manhattan          Queens
# 2025  10.30   5.76  61.86  yellow  credit card      Manhattan          Queens
# 2076  11.00   0.00  45.30  yellow  credit card      Manhattan          Queens
# 2122  16.27  17.28  81.35  yellow  credit card      Manhattan   Staten Island
# 2592  10.00   5.76  60.06  yellow  credit card      Manhattan          Queens
# 2763  11.41   5.76  68.47  yellow  credit card      Manhattan          Queens
# 3107  12.26   5.76  61.32  yellow  credit card      Manhattan          Queens
# 3405  10.76   5.76  53.82  yellow  credit card      Manhattan          Queens
# 3607  10.89   0.00  47.19  yellow  credit card      Manhattan       Manhattan
# 4081  11.45   0.00  57.25  yellow  credit card      Manhattan          Queens
# 4208  12.06  11.52  72.38  yellow  credit card      Manhattan   Staten Island
# 4317  10.31   5.76  61.87  yellow  credit card      Manhattan          Queens
# 4340  11.35   5.76  56.91  yellow  credit card      Manhattan          Queens
# 4416  10.20   0.00  51.00  yellow  credit card      Manhattan       Manhattan
# 4461  10.02   5.76  50.08  yellow  credit card      Manhattan          Queens
# 4532  10.26   0.00  61.56  yellow  credit card      Manhattan           Bronx
# 4553  10.29   0.00  44.59  yellow  credit card      Manhattan        Brooklyn
# 4831  10.60   5.76  53.16  yellow  credit card      Manhattan        Brooklyn
# 5178  12.51   5.76  62.57  yellow  credit card      Manhattan          Queens
# 5344  10.39   5.76  51.95  yellow  credit card      Manhattan          Queens
# 5767  10.71   0.00  64.26   green  credit card      Manhattan       Manhattan
#
#       distance_km
# 225     19.424734
# 501     15.530131
# 719     17.654460
# 745     25.926467
# 1179    17.123378
# 2025    20.760486
# 2076    15.980746
# 2122    24.960863
# 2592    19.473014
# 2763    25.475852
# 3107    16.962444
# 3405    17.976328
# 3607    17.461339
# 4081    17.332592
# 4208    26.071308
# 4317    20.100657
# 4340    16.415268
# 4416    18.941932
# 4461    14.918582
# 4532    27.020819
# 4553    14.097818
# 4831    18.990212
# 5178    22.595134
# 5344    17.364779
# 5767    18.732718

# %% [markdown]
# 12. Was ist die mittlere Fahrtstrecke im Datensatz? (Achtung, nicht mehr 'big_tips'!)

# %%
taxis['distance_km'].mean()
# Out:
# np.float64(4.8676368323332815)

# %% [markdown]
# 13. Was ist die mittlere Fahrtstrecke für Manhattan (Start)?<br>
# Unterscheidet sich diese, wenn Manhattan Ziel ist?

# %%
manhattan_taxi_rides = taxis[taxis['pickup_borough'] == 'Manhattan']
manhattan_mean_distance = manhattan_taxi_rides['distance_km'].mean()
manhattan_mean_distance
# Out:
# np.float64(3.7815029794229313)

# %%
taxi_rides_to_manhattan = taxis[taxis['dropoff_borough'] == 'Manhattan']
mean_distance_for_rides_to_manhattan = taxi_rides_to_manhattan['distance_km'].mean()
mean_distance_for_rides_to_manhattan
# Out:
# np.float64(3.8479733636573186)

# %% [markdown]
# 14. Lass es noch einmal krachen und slice einen Teil des DataFrames heraus, für den folgende Dinge gelten:
# * Die Taxis sind ausschließlich gelb
# * Es wurde ein Gesamtbetrag unter 10 Dollar gezahlt
# * Die Fahrtstrecke bewegt sich zwischen einer und drei Meilen
# * Die Fahrt startete in Brooklyn oder der Bronx, <br>wobei du für Letzteres die bereitgestellte Liste boroughs_of_interest nutzen sollst<br>
# <hr>
#
# Tipp: Formatiere das Ganze gut lesbar und lege Bedingungen fürs Slicing auf sprechende Variablen, damit der Code lesbarer wird.

# %%
boroughs_of_interest = ['Brooklyn', 'Bronx']

# %%
taxi_color = taxis['color'] == 'yellow'
taxi_fare = taxis['fare'] < 10
ride_distance = taxis['distance'].between(1, 3)
starting_boroughs = taxis['pickup_borough'].isin(boroughs_of_interest)
sliced_taxis = taxis[taxi_color & taxi_fare & ride_distance & starting_boroughs]

sliced_taxis
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 155  2019-03-21 22:49:32 2019-03-21 22:55:11           1      1.03   6.0
# 445  2019-03-19 06:57:14 2019-03-19 07:00:08           1      1.30   5.5
# 1666 2019-03-27 20:15:02 2019-03-27 20:25:04           2      1.40   8.0
# 1998 2019-03-04 13:59:55 2019-03-04 14:08:23           3      1.60   8.5
# 3555 2019-03-05 23:52:33 2019-03-06 00:03:32           1      1.70   9.5
# 3776 2019-03-08 08:03:22 2019-03-08 08:11:10           1      1.08   7.0
# 3898 2019-03-26 07:18:10 2019-03-26 07:26:51           2      1.67   7.5
# 4003 2019-03-08 03:08:40 2019-03-08 03:16:03           1      2.10   9.0
# 4027 2019-03-17 22:52:08 2019-03-17 22:57:55           1      1.09   6.0
# 4914 2019-03-16 23:48:32 2019-03-16 23:56:33           1      1.69   7.5
# 5190 2019-03-04 18:30:58 2019-03-04 18:40:11           1      2.20   9.0
#
#        tip  tolls  total   color      payment pickup_borough dropoff_borough  \
# 155   1.46    0.0   8.76  yellow  credit card       Brooklyn        Brooklyn
# 445   0.00    0.0   6.30  yellow          NaN       Brooklyn        Brooklyn
# 1666  0.00    0.0   9.30  yellow         cash       Brooklyn        Brooklyn
# 1998  0.00    0.0   9.30  yellow         cash          Bronx           Bronx
# 3555  0.00    0.0  10.80  yellow         cash       Brooklyn        Brooklyn
# 3776  2.34    0.0  10.14  yellow  credit card       Brooklyn        Brooklyn
# 3898  1.66    0.0   9.96  yellow  credit card       Brooklyn        Brooklyn
# 4003  0.00    0.0  10.30  yellow  credit card       Brooklyn        Brooklyn
# 4027  0.00    0.0   7.30  yellow         cash       Brooklyn        Brooklyn
# 4914  1.76    0.0  10.56  yellow  credit card       Brooklyn        Brooklyn
# 5190  2.15    0.0  12.95  yellow  credit card       Brooklyn        Brooklyn
#
#       distance_km
# 155      1.657620
# 445      2.092142
# 1666     2.253076
# 1998     2.574944
# 3555     2.735878
# 3776     1.738087
# 3898     2.687598
# 4003     3.379614
# 4027     1.754181
# 4914     2.719785
# 5190     3.540548
