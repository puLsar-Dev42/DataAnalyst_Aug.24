# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Dataset_FlexAppeal.csv")
data
# Out:
#       gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0          1              1        1              1      0                6
# 1          0              1        0              0      1               12
# 2          0              1        1              0      1                1
# 3          0              1        1              1      1               12
# 4          1              1        1              1      1                1
# ...      ...            ...      ...            ...    ...              ...
# 3995       1              1        1              0      1               12
# 3996       0              1        0              0      1                1
# 3997       1              1        1              1      1               12
# 3998       0              1        1              1      1                6
# 3999       1              0        1              0      0               12
#
# ...

# %%
ml_scores = pd.read_csv("ModellbewertungenFlexAppeal.csv")
ml_scores
# Out:
#    Mean(Error in %)  Standard deviation(Error in %)  Range(Error in %)   Error
# 0            18.050                        3.181981               4.50     NaN
# 1             9.925                        1.806816               5.75     NaN
# 2             8.425                        1.247497               3.50     NaN
# 3             7.125                        1.035817               3.00     NaN
# 4               NaN                             NaN                NaN  26.525
