# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
# Wir kriegen den Plot bei Jupyter immer unter dem Block angezeigt:
sns.lineplot(flights, x='year', y='passengers', errorbar=None);

# %%
# Wir können, müssen aber nicht plt.show benutzen:
sns.lineplot(flights, x='year', y='passengers', errorbar=None)
plt.show()
